# %%
from src.timeline import Timeline

# %%
# define colors for below
culture = "purple"
exploration = "C0"
religion = "C1"
disasters = "C3"
politics = "C2"

# %%
# create the timeline
timeline = Timeline()

# ---------------------------
# Ages
# ---------------------------
timeline.add_age(
    name="Early Middle Ages",
    start=476,
    end=1000,
    color="C1",
    url="https://en.wikipedia.org/wiki/Early_Middle_Ages",
)
timeline.add_age(
    name="High Middle Ages",
    start=1000,
    end=1300,
    color="C3",
    url="https://en.wikipedia.org/wiki/High_Middle_Ages",
)
timeline.add_age(
    name="Late Middle Ages",
    start=1300,
    end=1500,
    color="gold",
    url="https://en.wikipedia.org/wiki/Late_Middle_Ages",
)
timeline.add_age(
    name="Early Modern Period",
    start=1500,
    end=1800,
    color="C0",
    url="https://en.wikipedia.org/wiki/Early_modern_period",
)
timeline.add_age(
    name="Late\nModern\nPeriod",
    start=1800,
    end=1945,
    color="cornflowerblue",
    url="https://en.wikipedia.org/wiki/Late_modern_period",
)

# ---------------------------
# General Culture
# ---------------------------

timeline.add_event(
    name="Prose\nEdda",
    year=1220,
    y=0.85,
    color=culture,
    url="https://en.wikipedia.org/wiki/Prose_Edda",
)
timeline.add_event(
    name="Divine\nComedy",
    year=1321,
    y=0.85,
    color=culture,
    url="https://en.wikipedia.org/wiki/Divine_Comedy",
)
timeline.add_period(
    name="Renaissance",
    start=1400,
    end=1660,
    y=0.85,
    color=culture,
    fontsize=10,
    url="https://en.wikipedia.org/wiki/Renaissance",
)
timeline.add_event(
    name="Copernican Revolution",
    year=1543,
    y=0.8125,
    color=culture,
    url="https://en.wikipedia.org/wiki/Copernican_Revolution",
)
timeline.add_period(
    name="Scientific\nRevolution",
    start=1543,
    end=1687,
    y=0.775,
    color=culture,
    fontsize=9,
    url="https://en.wikipedia.org/wiki/Scientific_Revolution",
)
timeline.add_event(
    name="Don Quixote",
    year=1605,
    y=0.886,
    color=culture,
    fontsize=6,
    url="https://en.wikipedia.org/wiki/Don_Quixote",
)
timeline.add_period(
    name="Age of\nEnlightenment",
    start=1687,
    end=1800,
    y=0.85,
    color=culture,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Age_of_Enlightenment",
)
timeline.add_period(
    name="Industrial\nRevolution",
    start=1760,
    end=1840,
    y=0.775,
    color=culture,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Industrial_Revolution",
)
timeline.add_event(
    name="Birth of\nmodern\nphysics",
    year=1905,
    y=0.8125,
    color=culture,
    url="https://en.wikipedia.org/wiki/Annus_mirabilis_papers",
)

# ---------------------------
# Exploration
# ---------------------------
timeline.add_event(
    name="Leif Erikson\nFinds America",
    year=1000,
    y=0.775,
    color=exploration,
    url="https://en.wikipedia.org/wiki/Norse_colonization_of_North_America",
)
timeline.add_period(
    name="Marco Polo\ntravels\nSilk Road",
    start=1271,
    end=1295,
    y=0.775,
    color=exploration,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/The_Travels_of_Marco_Polo",
)
timeline.add_event(
    name="Columbus\nFinds\nAmerica",
    year=1492,
    y=0.775,
    color=exploration,
    url="https://en.wikipedia.org/wiki/Voyages_of_Christopher_Columbus",
)

# -----------------------------
# General Religious Events
# -----------------------------
timeline.add_event(
    name="Great\nSchism",
    year=1054,
    y=0.71,
    color=religion,
    url="https://en.wikipedia.org/wiki/East–West_Schism",
)
timeline.add_period(
    name="Crusades",
    start=1096,
    end=1270,
    y=0.71,
    color=religion,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Crusades",
)
timeline.add_period(
    name="Western\nSchism",
    start=1378,
    end=1417,
    y=0.71,
    color=religion,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Western_Schism",
)
timeline.add_period(
    name="Protestant\nReformation",
    start=1517,
    end=1648,
    y=0.71,
    color=religion,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Reformation",
)

# ---------------------------
# Other Pan-European Events
# ---------------------------

timeline.add_period(
    name="Barbarian Invasions",
    start=timeline.start,
    end=700,
    y=0.645,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Migration_Period",
)
timeline.add_period(
    name="Viking\nAge",
    start=793,
    end=1066,
    y=0.645,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Viking_Age",
)
timeline.add_period(
    name="Mongol\nInvasion",
    start=1223,
    end=1242,
    y=0.645,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Mongol_invasion_of_Europe",
)
timeline.add_period(
    name="Crisis of Late\nMiddle Ages",
    start=1315,
    end=1417,
    y=0.645,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Crisis_of_the_Late_Middle_Ages",
)
timeline.add_event(
    name="Great\nFamine",
    year=1315,
    y=0.69,
    color=disasters,
    url="https://en.wikipedia.org/wiki/Great_Famine_of_1315–1317",
)
timeline.add_event(
    name="Black Death",
    year=1346,
    y=0.61,
    color=disasters,
    url="https://en.wikipedia.org/wiki/Black_Death",
)
timeline.add_period(
    name="Age of\nRevolution",
    start=1765,
    end=1849,
    y=0.71,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Age_of_Revolution",
)
timeline.add_event(
    name="Congress of\nVienna",
    year=1814,
    y=0.645,
    color=politics,
    url="https://en.wikipedia.org/wiki/Congress_of_Vienna",
)
timeline.add_event(
    name="WW I",
    year=1914,
    y=0.655,
    color=disasters,
    url="https://en.wikipedia.org/wiki/World_War_I",
)
timeline.add_event(
    name="WW II",
    year=1939,
    y=0.635,
    color=disasters,
    url="https://en.wikipedia.org/wiki/World_War_II",
)

# ---------------------------
# Holy Roman Empire / Germany
# ---------------------------
germany = "Holy Roman Empire/\nGermany"
timeline.add_country(germany, 0.5, url="https://en.wikipedia.org/wiki/Holy_Roman_Empire")

timeline.add_period(
    name="Kingdom of\nthe Franks",
    start=496,
    end=843,
    y=timeline.countries[germany].y-0.1,
    h=0.05,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Francia",
)
timeline.add_event(
    name="Charlemagne\ncrowned King\nof the Romans",
    year=800,
    y=timeline.countries[germany].y-0.1,
    color="k",
    bold=False,
    url="https://en.wikipedia.org/wiki/Charlemagne",
)
timeline.add_event(
    name="Treaty of Verdun",
    year=843,
    y=timeline.countries[germany].y-0.02,
    color=politics,
    url="https://en.wikipedia.org/wiki/Treaty_of_Verdun",
)
timeline.add_period(
    name="East Francia",
    start=843,
    end=962,
    y=timeline.countries[germany].y-0.04,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/East_Francia",
)
timeline.add_period(
    name="Holy Roman Empire",
    start=962,
    end=1806,
    y=timeline.countries[germany].y-0.06,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Holy_Roman_Empire",
)
timeline.add_event(
    name="Nibelungenlied",
    year=1200,
    y=timeline.countries[germany].y+0.07,
    color=culture,
    url="https://en.wikipedia.org/wiki/Nibelungenlied",
)
timeline.add_period(
    name="Great Interregnum",
    start=1247,
    end=1273,
    y=timeline.countries[germany].y-0.035,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Interregnum_(Holy_Roman_Empire)",
)
timeline.add_period(
    name="Habsburg Dynasty",
    start=1438,
    end=1792,
    y=timeline.countries[germany].y-0.035,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Habsburg",
)
timeline.add_event(
    name="Printing\nPress",
    year=1440,
    y=timeline.countries[germany].y+0.07,
    color=culture,
    url="https://en.wikipedia.org/wiki/Printing_press",
)
timeline.add_period(
    name="Thirty\nYears'\nWar",
    start=1618,
    end=1648,
    y=timeline.countries[germany].y+0.02,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Thirty_Years%27_War",
)
timeline.add_event(
    name="Kant",
    year=1724,
    y=timeline.countries[germany].y+0.085,
    color=culture,
    url="https://en.wikipedia.org/wiki/Immanuel_Kant",
)
timeline.add_event(
    name="Goethe",
    year=1749,
    y=timeline.countries[germany].y+0.07,
    color=culture,
    url="https://en.wikipedia.org/wiki/Johann_Wolfgang_von_Goethe",
)
timeline.add_event(
    name="Mozart",
    year=1756,
    y=timeline.countries[germany].y+0.055,
    color=culture,
    url="https://en.wikipedia.org/wiki/Wolfgang_Amadeus_Mozart",
)
timeline.add_event(
    name="     Beethoven",
    year=1770,
    y=timeline.countries[germany].y+0.04,
    color=culture,
    url="https://en.wikipedia.org/wiki/Ludwig_van_Beethoven",
)
timeline.add_period(
    name="German\nConfederation",
    start=1815,
    end=1866,
    y=timeline.countries[germany].y-0.03,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/German_Confederation",
)
timeline.add_event(
    name="German\nRevolution",
    year=1848,
    y=timeline.countries[germany].y+0.005,
    color=disasters,
    url="https://en.wikipedia.org/wiki/Revolutions_of_1848#German_states",
)
timeline.add_period(
    name="German\nEmpire",
    start=1871,
    end=1918,
    y=timeline.countries[germany].y-0.0625,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/German_Empire",
)
timeline.add_period(
    name="Weimar\nRepublic",
    start=1918,
    end=1933,
    y=timeline.countries[germany].y-0.03,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Weimar_Republic",
)
timeline.add_period(
    name="Third\nReich",
    start=1933,
    end=1945,
    y=timeline.countries[germany].y-0.1,
    h=0.05,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Nazi_Germany",
)


# ---------------------------
# France
# ---------------------------
timeline.add_country("France", 0.3, url="https://en.wikipedia.org/wiki/History_of_France")

timeline.add_period(
    name="West Francia",
    start=843,
    end=987,
    y=timeline.countries["France"].y+0.04,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/West_Francia",
)
timeline.add_period(
    name="House of Capet",
    start=987,
    end=1328,
    y=timeline.countries["France"].y+0.06,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Capet",
)
timeline.add_event(
    name="Song of\nRoland",
    year=1040,
    y=timeline.countries["France"].y,
    color=culture,
    url="https://en.wikipedia.org/wiki/The_Song_of_Roland",
)
timeline.add_period(
    name="House of Valois",
    start=1328,
    end=1589,
    y=timeline.countries["France"].y+0.04,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Valois",
)
timeline.add_period(
    name="House of Bourbon",
    start=1589,
    end=1792,
    y=timeline.countries["France"].y+0.06,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Bourbon",
)
timeline.add_period(
    name="French\nRevolution",
    start=1789,
    end=1799,
    y=timeline.countries["France"].y-0.015,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/French_Revolution",
)
timeline.add_period(
    name="Napoleon",
    start=1799,
    end=1815,
    y=timeline.countries["France"].y+0.04,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Napoleonic_era",
)


# ---------------------------
# England
# ---------------------------
timeline.add_country("England", 0.10, url="https://en.wikipedia.org/wiki/History_of_England")

timeline.add_period(
    name="Anglo-Saxon\nInvasions",
    start=timeline.start,
    end=650,
    y=timeline.countries["England"].y-0.01,
    h=0.015,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Anglo-Saxon_settlement_of_Britain",
)
timeline.add_period(
    name="Heptarchy",
    start=timeline.start,
    end=829,
    y=timeline.countries["England"].y-0.04,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Heptarchy",
)
timeline.add_period(
    name="Christianization",
    start=595,
    end=686,
    y=timeline.countries["England"].y+0.03,
    h=0.015,
    color=religion,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Christianisation_of_Anglo-Saxon_England",
)
timeline.add_event(
    name="Beowulf",
    year=800,
    y=timeline.countries["England"].y+0.075,
    color=culture,
    url="https://en.wikipedia.org/wiki/Beowulf",
)
timeline.add_period(
    name="Danish\nInvasion",
    start=865,
    end=878,
    y=timeline.countries["England"].y-0.04,
    h=0.015,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Great_Heathen_Army",
)
timeline.add_period(
    name="Danelaw",
    start=878,
    end=1016,
    y=timeline.countries["England"].y-0.01,
    h=0.01,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Danelaw",
)
timeline.add_period(
    name="House of Wessex",
    start=886,
    end=1016,
    y=timeline.countries["England"].y-0.065,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Wessex",
)
timeline.add_period(
    name="W",
    start=1042,
    end=1066,
    y=timeline.countries["England"].y-0.065,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Wessex",
)
timeline.add_period(
    name="North Sea    \nEmpire",
    start=1016,
    end=1042,
    y=timeline.countries["England"].y-0.04,
    h=0.01,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/North_Sea_Empire",
)
timeline.add_event(
    name="Norman\nConquest",
    year=1066,
    y=timeline.countries["England"].y-0.002,
    color=disasters,
    url="https://en.wikipedia.org/wiki/Norman_Conquest",
)
timeline.add_period(
    name="House of\nNormandy",
    start=1066,
    end=1135,
    y=timeline.countries["England"].y-0.04,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Normandy",
)
timeline.add_event(
    name="Oxford",
    year=1096,
    y=timeline.countries["England"].y+0.055,
    color=culture,
    url="https://en.wikipedia.org/wiki/University_of_Oxford",
)
timeline.add_event(
    name="Sinking of\nWhite Ship",
    year=1120,
    y=timeline.countries["England"].y+0.03,
    color=disasters,
    url="https://en.wikipedia.org/wiki/White_Ship",
)
timeline.add_event(
    name="Historia Regum Britanniae",
    year=1136,
    y=timeline.countries["England"].y+0.09,
    color=culture,
    url="https://en.wikipedia.org/wiki/Historia_Regum_Britanniae",
)
timeline.add_period(
    name="The\nAnarchy",
    start=1139,
    end=1153,
    y=timeline.countries["England"].y-0.005,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/The_Anarchy",
)
timeline.add_event(
    name="Middle English",
    year=1150,
    y=timeline.countries["England"].y+0.072,
    color=culture,
    url="https://en.wikipedia.org/wiki/Middle_English",
)
timeline.add_period(
    name="House of Plantagenet",
    start=1154,
    end=1485,
    y=timeline.countries["England"].y-0.04,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Plantagenet",
)
timeline.add_period(
    name="Angevin",
    start=1154,
    end=1216,
    y=timeline.countries["England"].y-0.065,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Angevin_kings_of_England",
)
timeline.add_event(
    name="Magna\nCarta",
    year=1215,
    y=timeline.countries["England"].y-0.005,
    color=politics,
    url="https://en.wikipedia.org/wiki/Magna_Carta",
)
timeline.add_period(
    name="Hundred\nYears' War",
    start=1337,
    end=1453,
    y=timeline.countries["England"].y + 0.1,
    h=0.07,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Hundred_Years%27_War",
)
timeline.add_period(
    name="Lancaster",
    start=1399,
    end=1461,
    y=timeline.countries["England"].y-0.065,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Lancaster",
)
timeline.add_event(
    name="Canterbury\nTales",
    year=1400,
    y=timeline.countries["England"].y+0.015,
    color=culture,
    url="https://en.wikipedia.org/wiki/The_Canterbury_Tales",
)
timeline.add_period(
    name="Great Vowel Shift",
    start=1400,
    end=1700,
    y=timeline.countries["England"].y+0.07,
    h=0.01,
    color=culture,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Great_Vowel_Shift",
)
timeline.add_period(
    name="Wars of\nthe Roses",
    start=1455,
    end=1487,
    y=timeline.countries["England"].y + 0,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Wars_of_the_Roses",
)
timeline.add_period(
    name="York",
    start=1461,
    end=1485,
    y=timeline.countries["England"].y-0.088,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_York",
)
timeline.add_period(
    name="House of Tudor",
    start=1485,
    end=1603,
    y=timeline.countries["England"].y-0.065,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Tudor",
)
timeline.add_event(
    name="English\n  Reformation",
    year=1534,
    y=timeline.countries["England"].y - 0.03,
    color=religion,
    fontsize=6,
    url="https://en.wikipedia.org/wiki/English_Reformation",
)
timeline.add_event(
    name="Shakespeare",
    year=1564,
    y=timeline.countries["England"].y+0.09,
    color=culture,
    fontsize=6,
    url="https://en.wikipedia.org/wiki/William_Shakespeare",
)
timeline.add_period(
    name="              House of Stuart",
    start=1603,
    end=1649,
    y=timeline.countries["England"].y-0.04,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Stuart",
)
timeline.add_period(
    name="",
    start=1660,
    end=1714,
    y=timeline.countries["England"].y-0.04,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Stuart_period",
)
timeline.add_event(
    name="Gunpowder\nPlot",
    year=1605,
    y=timeline.countries["England"].y+0,
    color=disasters,
    url="https://en.wikipedia.org/wiki/Gunpowder_Plot",
)
timeline.add_event(
    name="King James\nBible",
    year=1611,
    y=timeline.countries["England"].y+0.045,
    color=culture,
    url="https://en.wikipedia.org/wiki/King_James_Version",
)
timeline.add_period(
    name="English Civil War",
    start=1642,
    end=1651,
    y=timeline.countries["England"].y-0.088,
    h=0.01,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/English_Civil_War",
)
timeline.add_period(
    name="Interregnum",
    start=1649,
    end=1660,
    y=timeline.countries["England"].y-0.065,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/Interregnum_(England)",
)
timeline.add_event(
    name="Principia",
    year=1687,
    y=timeline.countries["England"].y+0.09,
    color=culture,
    url="https://en.wikipedia.org/wiki/Philosophiæ_Naturalis_Principia_Mathematica",
)
timeline.add_event(
    name="Glorious\nRevolution",
    year=1688,
    y=timeline.countries["England"].y-0.01,
    color=disasters,
    url="https://en.wikipedia.org/wiki/Glorious_Revolution",
)
timeline.add_event(
    name="Great Britain\nFormed",
    year=1707,
    y=timeline.countries["England"].y+0.025,
    color=politics,
    url="https://en.wikipedia.org/wiki/Kingdom_of_Great_Britain",
)
timeline.add_period(
    name="House of Hanover",
    start=1714,
    end=1901,
    y=timeline.countries["England"].y-0.06,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Hanover",
)
timeline.add_period(
    name="American\nRevolution",
    start=1775,
    end=1783,
    y=timeline.countries["England"].y-0.02,
    color=disasters,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/American_Revolution",
)
timeline.add_event(
    name="United\nKingdom\nFormed",
    year=1801,
    y=timeline.countries["England"].y+0.035,
    color=politics,
    url="https://en.wikipedia.org/wiki/United_Kingdom_of_Great_Britain_and_Ireland",
)
timeline.add_event(
    name="Origin of\nSpecies",
    year=1859,
    y=timeline.countries["England"].y+0.08,
    color=culture,
    url="https://en.wikipedia.org/wiki/On_the_Origin_of_Species",
)
timeline.add_period(
    name="House of\nWindsor",
    start=1901,
    end=1945,
    y=timeline.countries["England"].y-0.04,
    h=0.01,
    color=politics,
    fontsize=8,
    url="https://en.wikipedia.org/wiki/House_of_Windsor",
)

fig = timeline.plot();
fig.savefig("timeline.pdf")
